# %%
import torch
import os

# %%
root_dir = "DL/ConvNorm/saved/models/"
BN_str = "large_Adv_trainingCIFAR10DataLoaderresnet18-num_classes-10-norm_layer_type-bn-conv_layer_type-conv-linear_layer_type-linear-activation_layer_type-relu-Seed="
CN_str = "large_Adv_trainingCIFAR10DataLoaderresnet18-num_classes-10-norm_layer_type-no-conv_layer_type-prec_conv-linear_layer_type-linear-activation_layer_type-relu-Seed="
ONI_str = "large_Adv_trainingCIFAR10DataLoaderresnet18-num_classes-10-norm_layer_type-bn-conv_layer_type-oni_conv-linear_layer_type-linear-activation_layer_type-relu-Seed="
SN_str = "large_Adv_trainingCIFAR10DataLoaderresnet18-num_classes-10-norm_layer_type-bn-conv_layer_type-sn_conv-linear_layer_type-linear-activation_layer_type-relu-Seed="
OCNN_str = "ocnn_0.0001_large_adv_trainingCIFAR10DataLoaderresnet18-num_classes-10-norm_layer_type-bn-conv_layer_type-conv-linear_layer_type-linear-activation_layer_type-relu-Seed="

# %%
seed_num = ["6/", "8/", "666/", "10/"]

# %% [markdown]
# ## PGD_20

# %%
# ConvNorm
for see in seed_num:
    print(see)
    total = root_dir + CN_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python validate_pgd.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# PGD attack with each step 0.00784313725490196 and a total of 20 steps, total eps 0.03137254901960784
# /scratch/xl998/DL/ConvNorm/models/prec_conv.py:105: UserWarning: The function torch.rfft is deprecated and will be removed in a future PyTorch release. Use the new torch.fft module functions, instead, by importing torch.fft and calling torch.fft.fft or torch.fft.rfft. (Triggered internally at  /opt/conda/conda-bld/pytorch_1607370151529/work/aten/src/ATen/native/SpectralOps.cpp:590.)
#   f_input = torch.rfft(cout, 2, normalized=False, onesided=True)
# ...

# %%
# Spectral Norm
for see in seed_num:
    print(see)
    total = root_dir + SN_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python validate_pgd.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# PGD attack with each step 0.00784313725490196 and a total of 20 steps, total eps 0.03137254901960784
# PGD Test: [0/100]	Loss 1.5054 (1.5054)	Prec@1 43.000 (43.000)	Prec@5 92.000 (92.000)
# PGD Test: [50/100]	Loss 1.6324 (1.5083)	Prec@1 42.000 (45.686)	Prec@5 90.000 (93.137)
#  PGD Final Prec@1 44.980 Prec@5 93.410
# 8/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# ...

# %%
# ONI
for see in seed_num:
    print(see)
    total = root_dir + ONI_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python validate_pgd.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# ONI channels:--OD: 64 --ID: 3 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 128 --ID: 64 --KS 3
# ONI channels:--OD: 128 --ID: 128 --KS 3
# ONI channels:--OD: 128 --ID: 64 --KS 1
# ONI channels:--OD: 128 --ID: 128 --KS 3
# ONI channels:--OD: 128 --ID: 128 --KS 3
# ONI channels:--OD: 256 --ID: 128 --KS 3
# ONI channels:--OD: 256 --ID: 256 --KS 3
# ONI channels:--OD: 256 --ID: 128 --KS 1
# ONI channels:--OD: 256 --ID: 256 --KS 3
# ONI channels:--OD: 256 --ID: 256 --KS 3
# ONI channels:--OD: 512 --ID: 256 --KS 3
# ONI channels:--OD: 512 --ID: 512 --KS 3
# ONI channels:--OD: 512 --ID: 256 --KS 1
# ONI channels:--OD: 512 --ID: 512 --KS 3
# ONI channels:--OD: 512 --ID: 512 --KS 3
# ...

# %% [markdown]
# ## FGSM

# %%
# Start FGSM here
# BatchNorm
for see in seed_num:
    print(see)
    total = root_dir + BN_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python fgsm.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# FGSM attack with capacity 0.03137254901960784
# FGSM Test: [0/100]	Loss 1.2912 (1.2912)	Prec@1 52.000 (52.000)	Prec@5 95.000 (95.000)
# FGSM Test: [49/100]	Loss 1.4416 (1.2910)	Prec@1 49.000 (52.360)	Prec@5 94.000 (94.620)
# FGSM Test: [99/100]	Loss 1.2365 (1.2939)	Prec@1 56.000 (51.750)	Prec@5 96.000 (94.580)
#  FGSM Final Prec@1 51.750 Prec@5 94.580
# 8/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# FGSM attack with capacity 0.03137254901960784
# FGSM Test: [0/100]	Loss 1.3369 (1.3369)	Prec@1 51.000 (51.000)	Prec@5 94.000 (94.000)
# FGSM Test: [49/100]	Loss 1.4107 (1.2867)	Prec@1 50.000 (52.860)	Prec@5 96.000 (94.720)
# FGSM Test: [99/100]	Loss 1.2524 (1.2887)	Prec@1 54.000 (52.410)	Prec@5 98.000 (94.820)
#  FGSM Final Prec@1 52.410 Prec@5 94.820
# 666/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# ...

# %%
# Start FGSM here
# ConvNorm
for see in seed_num:
    print(see)
    total = root_dir + CN_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python fgsm.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# FGSM attack with capacity 0.03137254901960784
# /scratch/xl998/DL/ConvNorm/models/prec_conv.py:105: UserWarning: The function torch.rfft is deprecated and will be removed in a future PyTorch release. Use the new torch.fft module functions, instead, by importing torch.fft and calling torch.fft.fft or torch.fft.rfft. (Triggered internally at  /opt/conda/conda-bld/pytorch_1607370151529/work/aten/src/ATen/native/SpectralOps.cpp:590.)
#   f_input = torch.rfft(cout, 2, normalized=False, onesided=True)
# /scratch/xl998/DL/ConvNorm/models/prec_conv.py:116: UserWarning: The function torch.irfft is deprecated and will be removed in a future PyTorch release. Use the new torch.fft module functions, instead, by importing torch.fft and calling torch.fft.ifft or torch.fft.irfft. (Triggered internally at  /opt/conda/conda-bld/pytorch_1607370151529/work/aten/src/ATen/native/SpectralOps.cpp:602.)
# ...

# %%
# Start FGSM here
# Spectral Norm
for see in seed_num:
    print(see)
    total = root_dir + SN_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python fgsm.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# torch.Size([512])
# FGSM attack with capacity 0.03137254901960784
# FGSM Test: [0/100]	Loss 1.3054 (1.3054)	Prec@1 56.000 (56.000)	Prec@5 93.000 (93.000)
# FGSM Test: [49/100]	Loss 1.4862 (1.2955)	Prec@1 48.000 (53.480)	Prec@5 93.000 (94.300)
# FGSM Test: [99/100]	Loss 1.2286 (1.2937)	Prec@1 53.000 (52.540)	Prec@5 95.000 (94.520)
#  FGSM Final Prec@1 52.540 Prec@5 94.520
# 8/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# ...

# %%
# Start FGSM here
# ONI
for see in seed_num:
    print(see)
    total = root_dir + ONI_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python fgsm.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# ONI channels:--OD: 64 --ID: 3 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 64 --ID: 64 --KS 3
# ONI channels:--OD: 128 --ID: 64 --KS 3
# ONI channels:--OD: 128 --ID: 128 --KS 3
# ONI channels:--OD: 128 --ID: 64 --KS 1
# ONI channels:--OD: 128 --ID: 128 --KS 3
# ONI channels:--OD: 128 --ID: 128 --KS 3
# ONI channels:--OD: 256 --ID: 128 --KS 3
# ONI channels:--OD: 256 --ID: 256 --KS 3
# ONI channels:--OD: 256 --ID: 128 --KS 1
# ONI channels:--OD: 256 --ID: 256 --KS 3
# ONI channels:--OD: 256 --ID: 256 --KS 3
# ONI channels:--OD: 512 --ID: 256 --KS 3
# ONI channels:--OD: 512 --ID: 512 --KS 3
# ONI channels:--OD: 512 --ID: 256 --KS 1
# ONI channels:--OD: 512 --ID: 512 --KS 3
# ONI channels:--OD: 512 --ID: 512 --KS 3
# FGSM attack with capacity 0.03137254901960784
# ...

# %%
# Start FGSM here
# OCNN
for see in seed_num:
    print(see)
    total = root_dir + OCNN_str + see
    for f in os.listdir(total):
        total += f
        if "model_epoch_30.pth" in os.listdir(total):
            model_path = "model_epoch_30.pth"
        else:
            model_path = "model_best.pth"
        total = total + "/" + model_path 
        ! python fgsm.py -c config_attack.json -s {total} --seed {int(see[:-1])}
# Out:
# 6/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# FGSM attack with capacity 0.03137254901960784
# FGSM Test: [0/100]	Loss 1.3484 (1.3484)	Prec@1 50.000 (50.000)	Prec@5 95.000 (95.000)
# FGSM Test: [49/100]	Loss 1.4514 (1.2853)	Prec@1 48.000 (53.320)	Prec@5 94.000 (94.820)
# FGSM Test: [99/100]	Loss 1.2301 (1.2815)	Prec@1 52.000 (52.800)	Prec@5 98.000 (94.850)
#  FGSM Final Prec@1 52.800 Prec@5 94.850
# 8/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# FGSM attack with capacity 0.03137254901960784
# FGSM Test: [0/100]	Loss 1.3116 (1.3116)	Prec@1 49.000 (49.000)	Prec@5 94.000 (94.000)
# FGSM Test: [49/100]	Loss 1.4273 (1.2912)	Prec@1 52.000 (52.800)	Prec@5 96.000 (94.980)
# FGSM Test: [99/100]	Loss 1.2567 (1.2904)	Prec@1 53.000 (52.280)	Prec@5 95.000 (94.760)
#  FGSM Final Prec@1 52.280 Prec@5 94.760
# 666/
# Start
# Doint adv. attack
# Files already downloaded and verified
# Test: 10000
# ...
